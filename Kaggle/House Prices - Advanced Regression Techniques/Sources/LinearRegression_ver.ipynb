# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
class LinearRegression:
  def __init__(self, lr = 0.001, n_iters = 1000):
    self.lr = lr
    self.n_iters = 1000
    self.weights = None
    self.bias = None

  def fit(self, X, y):
    n_samples, n_features = X.shape
    self.weights = np.zeros(n_features)
    self.bias = 0

    for _ in range(self.n_iters):
      y_pred = np.dot(X, self.weights) + self.bias

      dw = (1/n_samples) * np.dot(X, (y_pred - y))
      db = (1/n_samples) * np.sum(y_pred - y)

      self.weights = self.weights - self.lr * dw
      self.bias = self.bias - self.lr * db
  def predict(self, X):
    y_pred = np.dot(X, self.weights) + self.bias
    return y_pred

# %%
train = pd.read_csv("/content/drive/MyDrive/Machine Learning Code/House Prices - Advanced Regression Techniques/Data/train.csv")
test = pd.read_csv("/content/drive/MyDrive/Machine Learning Code/House Prices - Advanced Regression Techniques/Data/test.csv")
y = np.log(train.SalePrice)
X = train.drop(['SalePrice', 'Id', 'Alley'], axis = 1)
Reg = LinearRegression()
Reg.fit(X, y)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-973c53ce9848> in <cell line: 6>()
#       4 X = train.drop(['SalePrice', 'Id', 'Alley'], axis = 1)
#       5 Reg = LinearRegression()
# ----> 6 Reg.fit(X, y)
#
# <ipython-input-16-c47d5f1709de> in fit(self, X, y)
#      13
#      14     for _ in range(self.n_iters):
# ---> 15       y_pred = np.dot(X, self.weights) + self.bias
#      16
#      17       dw = (1/n_samples) * np.dot(X, (y_pred - y))
#
# /usr/local/lib/python3.10/dist-packages/numpy/core/overrides.py in dot(*args, **kwargs)
#
# TypeError: can't multiply sequence by non-int of type 'float'

# %%
select_var = ['Id','MSZoning','Utilities', 'Neighborhood','BldgType','HouseStyle',
                'OverallQual','OverallCond','YearBuilt', 'ExterQual','ExterCond',
                'BsmtQual','BsmtCond','TotalBsmtSF','Heating','HeatingQC',
                'CentralAir','Electrical','GrLivArea','BedroomAbvGr','KitchenAbvGr',
                'KitchenQual','TotRmsAbvGrd','Functional','Fireplaces','FireplaceQu',
               'GarageArea','GarageQual','GarageCond','OpenPorchSF','PoolArea',
                'Fence','MoSold','YrSold','SaleType','SaleCondition','SalePrice']
select_train = train[select_var]
print(select_train)
# Out:
#         Id MSZoning Utilities Neighborhood BldgType HouseStyle  OverallQual  \
# 0        1       RL    AllPub      CollgCr     1Fam     2Story            7
# 1        2       RL    AllPub      Veenker     1Fam     1Story            6
# 2        3       RL    AllPub      CollgCr     1Fam     2Story            7
# 3        4       RL    AllPub      Crawfor     1Fam     2Story            7
# 4        5       RL    AllPub      NoRidge     1Fam     2Story            8
# ...    ...      ...       ...          ...      ...        ...          ...
# 1455  1456       RL    AllPub      Gilbert     1Fam     2Story            6
# 1456  1457       RL    AllPub       NWAmes     1Fam     1Story            6
# 1457  1458       RL    AllPub      Crawfor     1Fam     2Story            7
# 1458  1459       RL    AllPub        NAmes     1Fam     1Story            5
# 1459  1460       RL    AllPub      Edwards     1Fam     1Story            5
#
# ...
